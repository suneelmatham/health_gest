# %%
import pandas as pd

# %%
import os
path = os.getcwd()
path
# Out:
# '/Users/mparvatham/Downloads/challengeLab-ML-master'

# %%
df_cfrna = pd.read_csv(path+'/data/train/cfRNA.csv')
df_cfrna.head()
# Out:
#   SampleID   C2orf76        ACTL10     CEP135  RP11-613M10.6      NDUFB5P1  \
# 0       K1  0.312437 -1.892930e-16  28.217854  -5.273559e-18 -6.106227e-18
# 1       I1  1.849737  0.000000e+00  54.567231   9.248683e-01  0.000000e+00
# 2       J1  5.204209  1.734736e+00  53.776824   0.000000e+00  0.000000e+00
# 3       P1  0.000000  0.000000e+00  15.269087   0.000000e+00  0.000000e+00
# 4       L1  0.000000  0.000000e+00  11.048308   0.000000e+00  0.000000e+00
#
#         MIIP  RP11-98I9.4     C20orf144  RP11-485G7.6  ...  LL22NC03-86G7.1  \
# 0  10.107555     0.070008 -3.885781e-16 -4.113376e-16  ...         0.707989
# 1  17.110064     2.774605  0.000000e+00  0.000000e+00  ...         0.000000
# 2   4.336841     1.734736  0.000000e+00  0.000000e+00  ...         1.734736
# 3   0.000000     0.000000  0.000000e+00  0.000000e+00  ...         3.053817
# 4  19.886954     2.209662  0.000000e+00  0.000000e+00  ...         0.000000
#
#        DNAL4      PPM1F     CCDC94      CLN6  RP11-500C11.3       CTBP2P7  \
# 0   4.504731  55.583978  14.308368  1.934940  -1.826317e-16 -2.797762e-16
# 1   7.398947  92.486832  16.647630  3.237039   4.624342e-01  0.000000e+00
# 2  10.408418  89.338918  19.949467  4.336841   8.673681e-01  0.000000e+00
# 3   0.000000  45.807261   9.161452  0.000000   0.000000e+00  0.000000e+00
# 4  26.515938  57.451200  37.564246  4.419323   0.000000e+00  0.000000e+00
#
#           ITIH2  RBPMSLP         ABCA8
# 0 -1.122435e-15        0 -1.474376e-15
# 1  4.624342e-01        0  0.000000e+00
# 2  8.673681e-01        0  0.000000e+00
# 3  0.000000e+00        0  0.000000e+00
# 4  0.000000e+00        0  2.209662e+00
#
# [5 rows x 37276 columns]

# %%
df_cfrna.describe()
# Out:
#          C2orf76        ACTL10      CEP135  RP11-613M10.6      NDUFB5P1  \
# count  68.000000  6.800000e+01   68.000000   6.800000e+01  6.800000e+01
# mean    2.109534  2.760670e-01   27.387847   2.796302e-02  8.118692e-03
# std     9.099555  1.175867e+00   37.406354   1.618914e-01  6.694845e-02
# min     0.000000 -1.892930e-16    0.000000  -5.273559e-18 -6.106227e-18
# 25%     0.000000  0.000000e+00    0.000000   0.000000e+00  0.000000e+00
# 50%     0.000000  0.000000e+00   20.226666   0.000000e+00  0.000000e+00
# 75%     0.312437  0.000000e+00   33.635706   0.000000e+00  0.000000e+00
# max    66.465301  8.409156e+00  247.816120   9.766169e-01  5.520711e-01
#
#             MIIP  RP11-98I9.4     C20orf144  RP11-485G7.6      CCDC86  ...  \
# count  68.000000    68.000000  6.800000e+01  6.800000e+01   68.000000  ...
# mean   12.074503     0.518756  5.349274e-01  3.542026e-01    7.486749  ...
# std    18.259793     1.261963  2.356001e+00  1.898470e+00   15.073761  ...
# min     0.000000     0.000000 -3.885781e-16 -4.113376e-16    0.000000  ...
# 25%     0.000000     0.000000  0.000000e+00  0.000000e+00    0.000000  ...
# 50%     7.844740     0.000000  0.000000e+00  0.000000e+00    2.455485  ...
# 75%    13.735287     0.070008  0.000000e+00  0.000000e+00    8.962902  ...
# max    78.170464     6.092119  1.312853e+01  1.149809e+01  104.843783  ...
#
#        LL22NC03-86G7.1       DNAL4        PPM1F     CCDC94       CLN6  \
# count        68.000000   68.000000    68.000000  68.000000  68.000000
# mean         39.713366    7.932288    61.362786  14.009628   3.812000
# std         157.073813   19.802993   140.813746  16.071416   7.092576
# min           0.000000    0.000000     0.000000   0.000000   0.000000
# 25%           0.000000    0.000000    15.766287   0.000000   0.000000
# 50%           0.707989    0.000000    47.152466  13.910094   0.000000
# 75%          13.592483    4.632898    68.310691  20.275548   4.779418
# max         980.872977  138.753989  1170.960187  95.521628  37.616611
#
#        RP11-500C11.3       CTBP2P7         ITIH2  RBPMSLP         ABCA8
# count   6.800000e+01  6.800000e+01  6.800000e+01     68.0  6.800000e+01
# mean    3.558720e-01  1.559718e-01  8.313246e-01      0.0  4.438656e-01
# std     1.686742e+00  9.224167e-01  2.948421e+00      0.0  1.688256e+00
# min    -1.826317e-16 -2.797762e-16 -1.122435e-15      0.0 -1.474376e-15
# 25%     0.000000e+00  0.000000e+00  0.000000e+00      0.0  0.000000e+00
# 50%     0.000000e+00  0.000000e+00  0.000000e+00      0.0  0.000000e+00
# 75%     0.000000e+00  0.000000e+00  0.000000e+00      0.0  0.000000e+00
# max     1.282971e+01  7.385033e+00  1.592027e+01      0.0  1.006816e+01
#
# [8 rows x 37275 columns]

# %%
df_meta = pd.read_csv(path+'/data/challenge-meta-information.csv')
df_meta.head()
# Out:
#    time    GA SampleID randPerson   data
# 0     1  11.0       K1          K  train
# 1     1  11.0       J1          J  train
# 2     1  11.0       P1          P  train
# 3     1  11.0       L1          L  train
# 4     1  11.0       H1          H  train

# %%
df=df_cfrna.merge(df_meta, on='SampleID')
df.head()
# Out:
#   SampleID   C2orf76        ACTL10     CEP135  RP11-613M10.6      NDUFB5P1  \
# 0       K1  0.312437 -1.892930e-16  28.217854  -5.273559e-18 -6.106227e-18
# 1       I1  1.849737  0.000000e+00  54.567231   9.248683e-01  0.000000e+00
# 2       J1  5.204209  1.734736e+00  53.776824   0.000000e+00  0.000000e+00
# 3       P1  0.000000  0.000000e+00  15.269087   0.000000e+00  0.000000e+00
# 4       L1  0.000000  0.000000e+00  11.048308   0.000000e+00  0.000000e+00
#
#         MIIP  RP11-98I9.4     C20orf144  RP11-485G7.6  ...      CLN6  \
# 0  10.107555     0.070008 -3.885781e-16 -4.113376e-16  ...  1.934940
# 1  17.110064     2.774605  0.000000e+00  0.000000e+00  ...  3.237039
# 2   4.336841     1.734736  0.000000e+00  0.000000e+00  ...  4.336841
# 3   0.000000     0.000000  0.000000e+00  0.000000e+00  ...  0.000000
# 4  19.886954     2.209662  0.000000e+00  0.000000e+00  ...  4.419323
#
#    RP11-500C11.3       CTBP2P7         ITIH2  RBPMSLP         ABCA8  time  \
# 0  -1.826317e-16 -2.797762e-16 -1.122435e-15        0 -1.474376e-15     1
# 1   4.624342e-01  0.000000e+00  4.624342e-01        0  0.000000e+00     1
# 2   8.673681e-01  0.000000e+00  8.673681e-01        0  0.000000e+00     1
# 3   0.000000e+00  0.000000e+00  0.000000e+00        0  0.000000e+00     1
# 4   0.000000e+00  0.000000e+00  0.000000e+00        0  2.209662e+00     1
#
#      GA  randPerson   data
# 0  11.0           K  train
# 1  11.0           I   test
# 2  11.0           J  train
# 3  11.0           P  train
# 4  11.0           L  train
#
# [5 rows x 37280 columns]

# %%
df_metab = pd.read_csv(path+'/data/train/metabolome.csv',encoding= 'unicode_escape')
df_metab.head()
# Out:
#   SampleID  \
# 0       K1
# 1       I1
# 2       J1
# 3       P1
# 4       L1
#
#    N1-Methyl-2-pyridone-5-carboxamide|N1-Methyl-4-pyridone-3-carboxamide|N-[(Aminooxy)Carbonyl]Aniline  \
# 0                                          -0.103676
# 1                                          -0.106104
# 2                                          -0.090160
# 3                                          -0.122656
# 4                                          -0.117107
#
#    Barringtogenol C|Camelliagenin C|Ganoderiol H|ED-71  \
# 0                                          -0.107316
# 1                                          -0.102340
# 2                                          -0.095522
# 3                                          -0.122855
# 4                                          -0.041200
#
#    3beta-Acetoxy-11alpha-methoxy-12-ursen-28-oic acid  Basilimoside  \
# 0                                          -0.114072      -0.123576
# 1                                          -0.114762      -0.112528
# 2                                          -0.104440      -0.111375
# 3                                          -0.119838      -0.121280
# 4                                          -0.079896      -0.085238
#
#    (2s)-Pyrrolidin-2-Ylmethylamine  4-Methylpiperazin-1-Yl Carbonyl Group  \
# 0                        -0.130470                              -0.129842
# 1                        -0.121543                              -0.121023
# 2                        -0.118311                              -0.116782
# 3                        -0.126312                              -0.125989
# 4                        -0.125743                              -0.125410
#
#    Chlorpromazine|Chlorpromazine  \
# 0                       0.458028
# 1                       0.581264
# 2                       1.165663
# 3                       0.548471
# 4                       0.596032
#
#    DG(15:0/18:4(6Z,9Z,12Z,15Z)/0:0)|DG(18:4(6Z,9Z,12Z,15Z)/15:0/0:0)|DG(15:0/0:0/18:4n3)  \
# 0                                          -0.125868
# 1                                          -0.107119
# 2                                          -0.114666
# 3                                          -0.122446
# 4                                          -0.083979
#
#    DG(15:0/18:3(6Z,9Z,12Z)/0:0)|DG(15:0/18:3(9Z,12Z,15Z)/0:0)|DG(18:3(6Z,9Z,12Z)/15:0/0:0)|DG(18:3(9Z,12Z,15Z)/15:0/0:0)|DG(15:0/0:0/18:3n6)|DG(15:0/0:0/18:3n3)|DG(14:1n5/0:0/18:2n6)|DG(14:1n5/0:0/20:2n6)  \
# 0                                          -0.091913
# 1                                          -0.060870
# 2                                          -0.066885
# 3                                          -0.088633
# 4                                           0.064603
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    PE(18:4(6Z,9Z,12Z,15Z)/P-18:1(11Z))|PE(18:4(6Z,9Z,12Z,15Z)/P-18:1(9Z))|PE(20:5(5Z,8Z,11Z,14Z,17Z)/P-16:0)|PE(P-16:0/20:5(5Z,8Z,11Z,14Z,17Z))|PE(P-18:1(11Z)/18:4(6Z,9Z,12Z,15Z))|PE(P-18:1(9Z)/18:4(6Z,9Z,12Z,15Z)).2  \
# 0                                          -0.023383
# 1                                          -0.088652
# 2                                          -0.096634
# 3                                          -0.068637
# 4                                          -0.071680
#
#    Glycerol triundecanoate.2  \
# 0                   0.058349
# 1                   0.111161
# 2                   0.245532
# 3                   0.406959
# 4                   0.417410
#
#    DG(15:0/18:2(9Z,12Z)/0:0)|DG(18:2(9Z,12Z)/15:0/0:0)|DG(14:0/0:0/18:2n6)|DG(14:0/0:0/20:2n6).5  \
# 0                                          -0.110397
# 1                                          -0.074311
# 2                                          -0.066543
# 3                                          -0.070162
# 4                                          -0.059560
#
#    beta-Casomorphin (1-6)  Glycerol triundecanoate.3  \
# 0               -0.129338                   0.058349
# 1               -0.120299                   0.111161
# 2               -0.117976                   0.245532
# 3               -0.124218                   0.406959
# 4               -0.124798                   0.417410
#
#    DG(15:0/18:1(11Z)/0:0)|DG(15:0/18:1(9Z)/0:0)|DG(18:1(11Z)/15:0/0:0)|DG(18:1(9Z)/15:0/0:0)|DG(15:0/0:0/18:1n7)|DG(15:0/0:0/18:1n9).1  \
# 0                                          -0.126018
# 1                                          -0.120831
# 2                                          -0.119000
# 3                                          -0.120697
# 4                                          -0.111645
#
#    Tetracosyl ferulate|Diisotridecyl phthalate|Ditridecyl phthalate.1  \
# 0                                          -0.127577
# 1                                          -0.109388
# 2                                          -0.113882
# 3                                          -0.124618
# 4                                          -0.119185
#
#    PE(14:0/20:2(11Z,14Z))|PE(14:1(9Z)/20:1(11Z))|PE(16:0/18:2(9Z,12Z))|PE(16:1(9Z)/18:1(11Z))|PE(16:1(9Z)/18:1(9Z))|PE(18:1(11Z)/16:1(9Z))|PE(18:1(9Z)/16:1(9Z))|PE(18:2(9Z,12Z)/16:0)|PE(20:1(11Z)/14:1(9Z))|PE(20:2(11Z,14Z)/14:0).2  \
# 0                                           0.471133
# 1                                           0.247993
# 2                                           0.216611
# 3                                           0.767959
# 4                                           0.272326
#
#    Isatoribine.2  Thelephoric acid|Triphenylantimony
# 0      -0.082986                           -0.111185
# 1      -0.064317                           -0.101570
# 2      -0.067518                           -0.100414
# 3      -0.094195                           -0.116142
# 4      -0.071258                           -0.105243
#
# [5 rows x 3486 columns]

# %%
df=df.merge(df_metab, on='SampleID')
df.head()
# Out:
#   SampleID   C2orf76        ACTL10     CEP135  RP11-613M10.6      NDUFB5P1  \
# 0       K1  0.312437 -1.892930e-16  28.217854  -5.273559e-18 -6.106227e-18
# 1       I1  1.849737  0.000000e+00  54.567231   9.248683e-01  0.000000e+00
# 2       J1  5.204209  1.734736e+00  53.776824   0.000000e+00  0.000000e+00
# 3       P1  0.000000  0.000000e+00  15.269087   0.000000e+00  0.000000e+00
# 4       L1  0.000000  0.000000e+00  11.048308   0.000000e+00  0.000000e+00
#
#         MIIP  RP11-98I9.4     C20orf144  RP11-485G7.6  ...  \
# 0  10.107555     0.070008 -3.885781e-16 -4.113376e-16  ...
# 1  17.110064     2.774605  0.000000e+00  0.000000e+00  ...
# 2   4.336841     1.734736  0.000000e+00  0.000000e+00  ...
# 3   0.000000     0.000000  0.000000e+00  0.000000e+00  ...
# 4  19.886954     2.209662  0.000000e+00  0.000000e+00  ...
#
#    PE(18:4(6Z,9Z,12Z,15Z)/P-18:1(11Z))|PE(18:4(6Z,9Z,12Z,15Z)/P-18:1(9Z))|PE(20:5(5Z,8Z,11Z,14Z,17Z)/P-16:0)|PE(P-16:0/20:5(5Z,8Z,11Z,14Z,17Z))|PE(P-18:1(11Z)/18:4(6Z,9Z,12Z,15Z))|PE(P-18:1(9Z)/18:4(6Z,9Z,12Z,15Z)).2  \
# 0                                          -0.023383
# 1                                          -0.088652
# 2                                          -0.096634
# 3                                          -0.068637
# 4                                          -0.071680
#
#    Glycerol triundecanoate.2  \
# 0                   0.058349
# 1                   0.111161
# 2                   0.245532
# 3                   0.406959
# 4                   0.417410
#
#    DG(15:0/18:2(9Z,12Z)/0:0)|DG(18:2(9Z,12Z)/15:0/0:0)|DG(14:0/0:0/18:2n6)|DG(14:0/0:0/20:2n6).5  \
# 0                                          -0.110397
# 1                                          -0.074311
# 2                                          -0.066543
# 3                                          -0.070162
# 4                                          -0.059560
#
#    beta-Casomorphin (1-6)  Glycerol triundecanoate.3  \
# 0               -0.129338                   0.058349
# 1               -0.120299                   0.111161
# 2               -0.117976                   0.245532
# 3               -0.124218                   0.406959
# 4               -0.124798                   0.417410
#
#    DG(15:0/18:1(11Z)/0:0)|DG(15:0/18:1(9Z)/0:0)|DG(18:1(11Z)/15:0/0:0)|DG(18:1(9Z)/15:0/0:0)|DG(15:0/0:0/18:1n7)|DG(15:0/0:0/18:1n9).1  \
# 0                                          -0.126018
# 1                                          -0.120831
# 2                                          -0.119000
# 3                                          -0.120697
# 4                                          -0.111645
#
#    Tetracosyl ferulate|Diisotridecyl phthalate|Ditridecyl phthalate.1  \
# 0                                          -0.127577
# 1                                          -0.109388
# 2                                          -0.113882
# 3                                          -0.124618
# 4                                          -0.119185
#
#    PE(14:0/20:2(11Z,14Z))|PE(14:1(9Z)/20:1(11Z))|PE(16:0/18:2(9Z,12Z))|PE(16:1(9Z)/18:1(11Z))|PE(16:1(9Z)/18:1(9Z))|PE(18:1(11Z)/16:1(9Z))|PE(18:1(9Z)/16:1(9Z))|PE(18:2(9Z,12Z)/16:0)|PE(20:1(11Z)/14:1(9Z))|PE(20:2(11Z,14Z)/14:0).2  \
# 0                                           0.471133
# 1                                           0.247993
# 2                                           0.216611
# 3                                           0.767959
# 4                                           0.272326
#
#    Isatoribine.2  Thelephoric acid|Triphenylantimony
# 0      -0.082986                           -0.111185
# 1      -0.064317                           -0.101570
# 2      -0.067518                           -0.100414
# 3      -0.094195                           -0.116142
# 4      -0.071258                           -0.105243
#
# [5 rows x 40765 columns]

# %%
df_micro = pd.read_csv(path+'/data/train/microbiome.csv')
df_micro.head()
# Out:
#   SampleID  VaginalSwab_Lactobacillus  Saliva_Lactobacillus  \
# 0       K1                 103.491092              0.435833
# 1       I1                   0.108275             -0.028496
# 2       J1                  -0.027296             -0.027296
# 3       P1                  -0.016359             -0.032342
# 4       L1                  -0.031554             -0.031554
#
#    ToothGum_Lactobacillus  Stool_Lactobacillus  VaginalSwab_Lactobacillus.1  \
# 0                0.004819             1.266310                   103.491092
# 1               -0.022462             0.057991                     0.108275
# 2               -0.027296            -0.027296                    -0.027296
# 3               -0.032342            -0.032342                    -0.016359
# 4               -0.031554            -0.031554                    -0.031554
#
#    Saliva_Lactobacillus.1  ToothGum_Lactobacillus.1  Stool_Lactobacillus.1  \
# 0                0.435833                  0.004819               1.266310
# 1               -0.028496                 -0.022462               0.057991
# 2               -0.027296                 -0.027296              -0.027296
# 3               -0.032342                 -0.032342              -0.032342
# 4               -0.031554                 -0.031554              -0.031554
#
#    VaginalSwab_Streptococcus  ...  ToothGum_Azospirillum  Stool_Azospirillum  \
# 0                  -0.004111  ...              -0.021970           -0.021970
# 1                  -0.028496  ...              -0.028496           -0.028496
# 2                  -0.027296  ...              -0.027296           -0.027296
# 3                  -0.032342  ...              -0.032342           -0.032342
# 4                  -0.031554  ...              -0.031554           -0.031554
#
#    VaginalSwab_Sphingomonas.5  Saliva_Sphingomonas.5  ToothGum_Sphingomonas.5  \
# 0                   -0.021970              -0.021970                -0.021970
# 1                   -0.028496              -0.028496                -0.028496
# 2                   -0.027296              -0.027296                -0.027296
# 3                   -0.032342              -0.032342                -0.032342
# 4                   -0.031554              -0.031554                -0.031554
#
#    Stool_Sphingomonas.5  VaginalSwab_Thalassospira.9  Saliva_Thalassospira.9  \
# 0             -0.021970                    -0.021970               -0.021970
# 1             -0.028496                    -0.028496               -0.028496
# 2             -0.027296                    -0.027296               -0.027296
# 3             -0.032342                    -0.032342               -0.032342
# 4             -0.031554                    -0.031554               -0.031554
#
#    ToothGum_Thalassospira.9  Stool_Thalassospira.9
# 0                 -0.021970              -0.021970
# 1                 -0.028496               0.204818
# 2                 -0.027296              -0.015173
# 3                 -0.032342              -0.032342
# 4                 -0.031554              -0.031554
#
# [5 rows x 18549 columns]

# %%
df=df.merge(df_micro, on='SampleID')
df.head()
# Out:
#   SampleID   C2orf76        ACTL10     CEP135  RP11-613M10.6      NDUFB5P1  \
# 0       K1  0.312437 -1.892930e-16  28.217854  -5.273559e-18 -6.106227e-18
# 1       I1  1.849737  0.000000e+00  54.567231   9.248683e-01  0.000000e+00
# 2       J1  5.204209  1.734736e+00  53.776824   0.000000e+00  0.000000e+00
# 3       P1  0.000000  0.000000e+00  15.269087   0.000000e+00  0.000000e+00
# 4       L1  0.000000  0.000000e+00  11.048308   0.000000e+00  0.000000e+00
#
#         MIIP  RP11-98I9.4     C20orf144  RP11-485G7.6  ...  \
# 0  10.107555     0.070008 -3.885781e-16 -4.113376e-16  ...
# 1  17.110064     2.774605  0.000000e+00  0.000000e+00  ...
# 2   4.336841     1.734736  0.000000e+00  0.000000e+00  ...
# 3   0.000000     0.000000  0.000000e+00  0.000000e+00  ...
# 4  19.886954     2.209662  0.000000e+00  0.000000e+00  ...
#
#    ToothGum_Azospirillum  Stool_Azospirillum  VaginalSwab_Sphingomonas.5  \
# 0              -0.021970           -0.021970                   -0.021970
# 1              -0.028496           -0.028496                   -0.028496
# 2              -0.027296           -0.027296                   -0.027296
# 3              -0.032342           -0.032342                   -0.032342
# 4              -0.031554           -0.031554                   -0.031554
#
#    Saliva_Sphingomonas.5  ToothGum_Sphingomonas.5  Stool_Sphingomonas.5  \
# 0              -0.021970                -0.021970             -0.021970
# 1              -0.028496                -0.028496             -0.028496
# 2              -0.027296                -0.027296             -0.027296
# 3              -0.032342                -0.032342             -0.032342
# 4              -0.031554                -0.031554             -0.031554
#
#    VaginalSwab_Thalassospira.9  Saliva_Thalassospira.9  \
# 0                    -0.021970               -0.021970
# 1                    -0.028496               -0.028496
# 2                    -0.027296               -0.027296
# 3                    -0.032342               -0.032342
# 4                    -0.031554               -0.031554
#
#    ToothGum_Thalassospira.9  Stool_Thalassospira.9
# 0                 -0.021970              -0.021970
# 1                 -0.028496               0.204818
# 2                 -0.027296              -0.015173
# 3                 -0.032342              -0.032342
# 4                 -0.031554              -0.031554
#
# [5 rows x 59313 columns]

# %%
df_copy = df.copy()

# %%
train = df[df.data == 'train']
test = df[df.data == 'test']

# %%
len(test)
# Out:
# 12

# %%
y_train = train.GA
y_test = test.GA

# %%
X_train = train.drop(['GA','time','randPerson','SampleID','data'], axis=1)
X_test = test.drop(['GA','time','randPerson','SampleID','data'], axis=1)

# %%
X_test.head()
# Out:
#      C2orf76    ACTL10     CEP135  RP11-613M10.6  NDUFB5P1       MIIP  \
# 1   1.849737  0.000000  54.567231       0.924868  0.000000  17.110064
# 12  1.425523  0.000000  44.191208       0.000000  0.000000  12.829706
# 13  0.000000  0.000000   0.000000       0.000000  0.000000   0.000000
# 18  3.864497  0.552071  45.821899       0.000000  0.552071  14.905919
# 29  0.000000  0.000000  33.506654       0.000000  0.000000   3.046059
#
#     RP11-98I9.4  C20orf144  RP11-485G7.6     CCDC86  ...  \
# 1      2.774605   0.000000           0.0  14.797893  ...
# 12     4.276569   0.000000           0.0   7.127614  ...
# 13     0.000000   0.000000           0.0   0.000000  ...
# 18     0.552071   1.656213           0.0  12.145563  ...
# 29     6.092119   0.000000           0.0   0.000000  ...
#
#     ToothGum_Azospirillum  Stool_Azospirillum  VaginalSwab_Sphingomonas.5  \
# 1               -0.028496           -0.028496                   -0.028496
# 12              -0.026713           -0.026713                   -0.026713
# 13              -0.034209           -0.034209                   -0.034209
# 18              -0.026282           -0.026282                   -0.026282
# 29              -0.024147           -0.024147                   -0.024147
#
#     Saliva_Sphingomonas.5  ToothGum_Sphingomonas.5  Stool_Sphingomonas.5  \
# 1               -0.028496                -0.028496             -0.028496
# 12              -0.026713                -0.026713             -0.026713
# 13              -0.034209                -0.034209             -0.034209
# 18              -0.026282                -0.026282             -0.026282
# 29              -0.024147                -0.024147             -0.024147
#
#     VaginalSwab_Thalassospira.9  Saliva_Thalassospira.9  \
# 1                     -0.028496               -0.028496
# 12                    -0.026713               -0.026713
# 13                    -0.034209               -0.034209
# 18                    -0.026282               -0.026282
# 29                    -0.024147               -0.024147
#
#     ToothGum_Thalassospira.9  Stool_Thalassospira.9
# 1                  -0.028496               0.204818
# 12                 -0.026713              -0.026713
# 13                 -0.034209              -0.034209
# 18                 -0.026282               0.019252
# 29                 -0.024147              -0.024147
#
# [5 rows x 59308 columns]

# %%
# Feature scaling
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler

num_pipeline = Pipeline([('min_max_scaler', MinMaxScaler())])
X_train_tr = num_pipeline.fit_transform(X_train)
# Out:
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %% [markdown]
# ## Random Forest

# %%
# Random forest
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100 ,random_state=1)
rf_model.fit(X_train_tr, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
# training error
from sklearn.metrics import mean_absolute_error

preds_train = rf_model.predict(X_train_tr)
rf_train_err = mean_absolute_error(y_train, preds_train)
rf_train_err
# Out:
# 1.2392857142857143

# %%
# Cross Validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(rf_model, X_train_tr, y_train, 
                         scoring ='neg_mean_absolute_error', cv=10)
def display_scores(scores):
    print('Scores:', scores)
    print('Mean: ', scores.mean())
    print('Standard Deviation:', scores.std())
    
display_scores(-scores)
# Out:
# Scores: [4.43571429 3.5797619  2.40880952 3.23       3.29428571 3.16380952
#  7.91742857 2.92       2.62342857 4.16542857]
# Mean:  3.7738666666666667
# Standard Deviation: 1.5037313779568995

# %%
rf_valid_err = -scores.mean()
rf_valid_err
# Out:
# 3.7738666666666667

# %%
# Saving model
import joblib

joblib.dump(rf_model, 'rf_model.pkl')
# Out:
# ['rf_model.pkl']

# %%
from sklearn.model_selection import GridSearchCV

# %%
# 'max_features':[2,4,6,8]}
param_grid = [{'n_estimators':[10,100,1000]},
             {'bootstrap':[False],'n_estimators':[10,100,1000]}]
forest_reg = RandomForestRegressor()
grid_search = GridSearchCV(forest_reg, param_grid, cv=10, scoring ='neg_mean_absolute_error'
                          , return_train_score = True)
grid_search.fit(X_train_tr, y_train)

# %%
grid_search.best_params_
# Out:
# {'n_estimators': 1000}

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres['mean_test_score'], cvres['params']):
    print(-mean_score, params)
# Out:
# 4.052040816326531 {'n_estimators': 10}
# 3.893112244897959 {'n_estimators': 100}
# 3.619408163265303 {'n_estimators': 1000}
# 4.8025510204081625 {'bootstrap': False, 'n_estimators': 10}
# 4.53359693877551 {'bootstrap': False, 'n_estimators': 100}
# 4.537772959183672 {'bootstrap': False, 'n_estimators': 1000}

# %% [markdown]
# ## Elastic Net

# %%
from sklearn.linear_model import ElasticNet
elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5)
elastic_net.fit(X_train_tr, y_train)
# Out:
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
# Training error
preds_train = elastic_net.predict(X_train_tr)
mean_absolute_error(y_train, preds_train)
# Out:
# 0.7256881681612628

# %%
scores = cross_val_score(elastic_net, X_train_tr, y_train, 
                         scoring ='neg_mean_absolute_error', cv=10)
display_scores(-scores)
# Out:
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# Scores: [4.81644078 2.0031888  2.34632603 1.13169433 3.79825771 3.03990207
#  6.59063467 4.06093473 4.00292906 5.04089978]
# Mean:  3.68312079682987
# Standard Deviation: 1.5288097073891012

# %%
joblib.dump(elastic_net, 'elastic_net.pkl')
# Out:
# ['elastic_net.pkl']

# %%
param_grid = [{'alpha':[0.1,0.5,0.8], 'l1_ratio':[0.1,0.5,0.8]}]
elastic_reg = ElasticNet()
grid_search = GridSearchCV(elastic_reg, param_grid, cv=10, scoring ='neg_mean_absolute_error'
                          , return_train_score = True)
enet_model = grid_search.fit(X_train_tr, y_train)
# Out:
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:842: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
grid_search.best_params_
# Out:
# {'alpha': 0.1, 'l1_ratio': 0.5}

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres['mean_test_score'], cvres['params']):
    print(-mean_score, params)
# Out:
# 4.6700325668478655 {'alpha': 0.1, 'l1_ratio': 0.1}
# 3.5944973135726905 {'alpha': 0.1, 'l1_ratio': 0.5}
# 3.6504588211117692 {'alpha': 0.1, 'l1_ratio': 0.8}
# 5.060789016929587 {'alpha': 0.5, 'l1_ratio': 0.1}
# 4.81310683726352 {'alpha': 0.5, 'l1_ratio': 0.5}
# 4.942815606123057 {'alpha': 0.5, 'l1_ratio': 0.8}
# 5.315775065549813 {'alpha': 0.8, 'l1_ratio': 0.1}
# 5.63490584700709 {'alpha': 0.8, 'l1_ratio': 0.5}
# 5.873241144646654 {'alpha': 0.8, 'l1_ratio': 0.8}

# %%
y_preds = enet_model.predict(X_train_tr)
enet_train_err = mean_absolute_error(y_train, y_preds)
enet_train_err
# Out:
# 0.7256881681612628

# %%
enet_valid_err = min(-cvres['mean_test_score'])
enet_valid_err
# Out:
# 3.5944973135726905

# %% [markdown]
# ## Neural net

# %%
import tensorflow as tf
from tensorflow import keras
keras.__version__
# Out:
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# '2.2.4-tf'

# %%
tf.__version__
# Out:
# '1.13.1'

# %%
X_train_tr.shape[1:]
# Out:
# (59308,)

# %%
from sklearn.model_selection import train_test_split

X_train_tr1, X_valid, y_train1, y_valid = train_test_split(X_train_tr, y_train )

# %%
model = keras.models.Sequential([keras.layers.Dense(300, activation='relu',
                                                   input_shape=X_train_tr.shape[1:]),
                                  keras.layers.Dense(150, activation ='relu'),
                                keras.layers.Dense(1)])
model.compile(loss='mean_absolute_error', optimizer='sgd')
history = model.fit(X_train_tr1, y_train1, epochs=20, validation_data = [X_valid, y_valid])
# Out:
# WARNING:tensorflow:From /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Train on 42 samples, validate on 14 samples
# WARNING:tensorflow:From /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 42/42 [==============================] - 1s 18ms/sample - loss: 14.2410 - val_loss: 11.1499
# Epoch 2/20
# 42/42 [==============================] - 0s 6ms/sample - loss: 12.3817 - val_loss: 19.5269
# Epoch 3/20
# 42/42 [==============================] - 0s 8ms/sample - loss: 15.6145 - val_loss: 10.5310
# Epoch 4/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 11.9179 - val_loss: 11.1803
# Epoch 5/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 8.9899 - val_loss: 9.1949
# Epoch 6/20
# 42/42 [==============================] - 0s 8ms/sample - loss: 8.4546 - val_loss: 10.9839
# Epoch 7/20
# 42/42 [==============================] - 0s 9ms/sample - loss: 9.7296 - val_loss: 17.1330
# Epoch 8/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 12.2109 - val_loss: 10.4783
# Epoch 9/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 12.1140 - val_loss: 9.1649
# Epoch 10/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 8.4859 - val_loss: 9.3761
# Epoch 11/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 8.1319 - val_loss: 9.2220
# Epoch 12/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 9.8522 - val_loss: 9.7791
# Epoch 13/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 9.9037 - val_loss: 9.7561
# Epoch 14/20
# 42/42 [==============================] - 0s 8ms/sample - loss: 7.8238 - val_loss: 12.7317
# Epoch 15/20
# 42/42 [==============================] - 0s 8ms/sample - loss: 9.1262 - val_loss: 9.3115
# Epoch 16/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 7.8482 - val_loss: 9.7142
# Epoch 17/20
# 42/42 [==============================] - 0s 6ms/sample - loss: 9.5070 - val_loss: 10.0053
# Epoch 18/20
# 42/42 [==============================] - 0s 9ms/sample - loss: 7.3538 - val_loss: 10.7554
# Epoch 19/20
# 42/42 [==============================] - 0s 9ms/sample - loss: 7.3068 - val_loss: 13.8814
# Epoch 20/20
# 42/42 [==============================] - 0s 8ms/sample - loss: 11.9053 - val_loss: 9.0674

# %%
history = model.fit(X_train_tr1, y_train1, epochs=20, validation_data = [X_valid, y_valid])
# Out:
# Train on 42 samples, validate on 14 samples
# Epoch 1/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 5.4721 - val_loss: 9.7042
# Epoch 2/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 3.9705 - val_loss: 9.7298
# Epoch 3/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 2.9993 - val_loss: 8.5156
# Epoch 4/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 2.6662 - val_loss: 9.1238
# Epoch 5/20
# 42/42 [==============================] - 0s 4ms/sample - loss: 3.3947 - val_loss: 9.0166
# Epoch 6/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 3.6311 - val_loss: 9.8892
# Epoch 7/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 3.9813 - val_loss: 10.5496
# Epoch 8/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 5.6342 - val_loss: 9.5113
# Epoch 9/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 3.0715 - val_loss: 10.4829
# Epoch 10/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 5.1219 - val_loss: 8.9134
# Epoch 11/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 1.7664 - val_loss: 8.2144
# Epoch 12/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 3.0604 - val_loss: 8.9686
# Epoch 13/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 3.0144 - val_loss: 9.9527
# Epoch 14/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 5.9836 - val_loss: 9.0271
# Epoch 15/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 2.3889 - val_loss: 9.2815
# Epoch 16/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 3.0894 - val_loss: 10.3334
# Epoch 17/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 5.4857 - val_loss: 8.5743
# Epoch 18/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 4.6770 - val_loss: 11.1636
# Epoch 19/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 7.2285 - val_loss: 9.5096
# Epoch 20/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 2.9849 - val_loss: 8.9584

# %%
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
#plt.gca().set_ylim(0,1)
plt.show()

# %%
mlp_train_err = model.evaluate(X_train_tr, y_train)
mlp_train_err
# Out:
# 56/56 [==============================] - 0s 1ms/sample - loss: 3.6142
# 3.6142473220825195

# %%
mlp_valid_err = model.evaluate(X_valid, y_valid)
mlp_valid_err
# Out:
# 14/14 [==============================] - 0s 874us/sample - loss: 8.9584
# 8.958413124084473

# %% [markdown]
# ## Test Set

# %%
X_test_tr = num_pipeline.transform(X_test)

# %%
rf_test_preds = rf_model.predict(X_test_tr)
rf_test_err = mean_absolute_error(y_test,rf_test_preds)
rf_test_err
# Out:
# 3.3448809523809526

# %%
enet_test_preds = enet_model.predict(X_test_tr)
enet_test_err = mean_absolute_error(y_test,enet_test_preds)
enet_test_err
# Out:
# 2.8030768833250104

# %%
mlp_test_err = model.evaluate(X_test_tr, y_test)
mlp_test_err
# Out:
# 12/12 [==============================] - 0s 987us/sample - loss: 416266546701139968.0000
# 4.1626654670114e+17

# %%
data = {'Random Forest':[rf_train_err, rf_valid_err, rf_test_err],
        'Elastic Net':[enet_train_err, enet_valid_err, enet_test_err],
        'MLP':[mlp_train_err, mlp_valid_err, mlp_test_err]}
results = pd.DataFrame(data, index=['train_mae','valid_mae','test_mae'])
results
# Out:
#            Random Forest  Elastic Net           MLP
# train_mae       1.239286     0.725688  3.614247e+00
# valid_mae       3.773867     3.594497  8.958413e+00
# test_mae        3.344881     2.803077  4.162665e+17

# %%
rf_test_preds
# Out:
# array([16.68142857, 13.47428571, 13.15428571, 18.70571429, 14.68      ,
#        18.36285714, 26.28      , 17.16571429, 25.32571429, -0.31714286,
#         0.46285714,  5.22571429])

# %%
test
# Out:
#    SampleID    C2orf76    ACTL10     CEP135  RP11-613M10.6  NDUFB5P1  \
# 1        I1   1.849737  0.000000  54.567231       0.924868  0.000000
# 12       W1   1.425523  0.000000  44.191208       0.000000  0.000000
# 13       B1   0.000000  0.000000   0.000000       0.000000  0.000000
# 18       I2   3.864497  0.552071  45.821899       0.000000  0.552071
# 29       W2   0.000000  0.000000  33.506654       0.000000  0.000000
# 30       B2   0.000000  0.000000  34.022863       0.000000  0.000000
# 35       I3   0.000000  0.000000   2.954576       0.000000  0.000000
# 46       W3  66.465301  0.000000   0.000000       0.000000  0.000000
# 47       B3   0.000000  0.000000  97.646714       0.000000  0.000000
# 52       I4   3.323430  0.000000  13.293718       0.000000  0.000000
# 63       W4  35.254263  0.000000   3.204933       0.000000  0.000000
# 64       B4   0.000000  0.000000   0.000000       0.000000  0.000000
#
#          MIIP  RP11-98I9.4  C20orf144  RP11-485G7.6  ...  \
# 1   17.110064     2.774605   0.000000           0.0  ...
# 12  12.829706     4.276569   0.000000           0.0  ...
# 13   0.000000     0.000000   0.000000           0.0  ...
# 18  14.905919     0.552071   1.656213           0.0  ...
# 29   3.046059     6.092119   0.000000           0.0  ...
# 30   0.000000     0.000000   0.000000           0.0  ...
# 35  32.500340     0.000000   0.000000           0.0  ...
# 46   0.000000     0.000000   0.000000           0.0  ...
# 47   0.000000     0.000000   0.000000           0.0  ...
# 52   0.000000     3.323430   0.000000           0.0  ...
# 63   9.614799     0.000000   0.000000           0.0  ...
# 64   0.000000     0.000000   0.000000           0.0  ...
#
#     ToothGum_Azospirillum  Stool_Azospirillum  VaginalSwab_Sphingomonas.5  \
# 1               -0.028496           -0.028496                   -0.028496
# 12              -0.026713           -0.026713                   -0.026713
# 13              -0.034209           -0.034209                   -0.034209
# 18              -0.026282           -0.026282                   -0.026282
# 29              -0.024147           -0.024147                   -0.024147
# 30              -0.034891           -0.034891                   -0.034891
# 35              -0.028956           -0.028956                   -0.028956
# 46              -0.034100           -0.034100                   -0.034100
# 47              -0.025123           -0.025123                   -0.025123
# 52              -0.028496           -0.028496                   -0.028496
# 63              -0.026713           -0.026713                   -0.026713
# 64              -0.034209           -0.034209                   -0.034209
#
#     Saliva_Sphingomonas.5  ToothGum_Sphingomonas.5  Stool_Sphingomonas.5  \
# 1               -0.028496                -0.028496             -0.028496
# 12              -0.026713                -0.026713             -0.026713
# 13              -0.034209                -0.034209             -0.034209
# 18              -0.026282                -0.026282             -0.026282
# 29              -0.024147                -0.024147             -0.024147
# 30              -0.034891                -0.034891             -0.034891
# 35              -0.028956                -0.028956             -0.028956
# 46              -0.034100                -0.034100             -0.034100
# 47              -0.025123                -0.025123             -0.025123
# 52              -0.028496                -0.028496             -0.028496
# 63              -0.026713                -0.026713             -0.026713
# 64              -0.034209                -0.034209             -0.034209
#
#     VaginalSwab_Thalassospira.9  Saliva_Thalassospira.9  \
# 1                     -0.028496               -0.028496
# 12                    -0.026713               -0.026713
# 13                    -0.034209               -0.034209
# 18                    -0.026282               -0.026282
# 29                    -0.024147               -0.024147
# 30                    -0.034891               -0.034891
# 35                    -0.028956               -0.028956
# 46                    -0.034100               -0.034100
# 47                    -0.025123               -0.025123
# 52                    -0.028496               -0.028496
# 63                    -0.026713               -0.026713
# 64                    -0.034209               -0.034209
#
#     ToothGum_Thalassospira.9  Stool_Thalassospira.9
# 1                  -0.028496               0.204818
# 12                 -0.026713              -0.026713
# 13                 -0.034209              -0.034209
# 18                 -0.026282               0.019252
# 29                 -0.024147              -0.024147
# 30                 -0.034891              -0.034891
# 35                 -0.028956               0.020993
# 46                 -0.034100              -0.034100
# 47                 -0.025123              -0.025123
# 52                 -0.028496               0.204818
# 63                 -0.026713              -0.026713
# 64                 -0.034209              -0.034209
#
# [12 rows x 59313 columns]

# %%
df_sub = test[['SampleID','GA']]
df_sub
# Out:
#    SampleID         GA
# 1        I1  11.000000
# 12       W1  11.000000
# 13       B1  11.000000
# 18       I2  15.000000
# 29       W2  18.000000
# 30       B2  16.000000
# 35       I3  25.000000
# 46       W3  27.000000
# 47       B3  27.000000
# 52       I4   2.571429
# 63       W4   0.571429
# 64       B4   0.571429

# %%
df_sub['predicted.GA'] = rf_test_preds
df_sub
# Out:
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    SampleID         GA  predicted.GA
# 1        I1  11.000000     16.681429
# 12       W1  11.000000     13.474286
# 13       B1  11.000000     13.154286
# 18       I2  15.000000     18.705714
# 29       W2  18.000000     14.680000
# 30       B2  16.000000     18.362857
# 35       I3  25.000000     26.280000
# 46       W3  27.000000     17.165714
# 47       B3  27.000000     25.325714
# 52       I4   2.571429     -0.317143
# 63       W4   0.571429      0.462857
# 64       B4   0.571429      5.225714

# %%
df_sub.to_csv('GROUP-4--SC2--ElasticNet.csv')
