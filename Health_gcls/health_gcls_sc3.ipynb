# %%
import pandas as pd

# %%
import os
path = os.getcwd()
path
# Out:
# '/Users/mparvatham/Downloads/challengeLab-ML-master'

# %%
df_immun = pd.read_csv(path +'/data/train/immunome.csv')
df_immun.head()
# Out:
#   SampleID    Bcells  CD16+CD56-NKcells  CD4+Tcells_mem  CD4+Tcells_naive  \
# 0       K4  0.053164           0.054978        0.297875          0.136289
# 1       I4  0.137333           0.061311        0.274281          0.139593
# 2       J4  0.103067           0.004128        0.162746          0.103950
# 3       P4  0.149802           0.058161        0.141881          0.257104
# 4       L4  0.124177           0.037422        0.235283          0.132742
#
#    CD4+Tcells  CD45RA+Tregs  CD45RA-Tregs  CD56+CD16-NKcells  CD7+NKcells  \
# 0    0.445832      0.002570      0.013848           0.007052     0.070836
# 1    0.422238      0.004931      0.013510           0.004393     0.075063
# 2    0.270840      0.003198      0.007988           0.007153     0.090763
# 3    0.406758      0.013168      0.009568           0.002663     0.069008
# 4    0.374535      0.003886      0.008935           0.001813     0.044584
#
#    ...  M-MDSC_STAT5_Unstim  mDCs_STAT5_Unstim  ncMCs_STAT5_Unstim  \
# ...

# %%
df_immun.describe()
# Out:
#           Bcells  CD16+CD56-NKcells  CD4+Tcells_mem  CD4+Tcells_naive  \
# count  68.000000          68.000000       68.000000         68.000000
# mean    0.088664           0.040560        0.219791          0.166037
# std     0.032683           0.032928        0.042841          0.069334
# min     0.028000           0.004128        0.127551          0.048464
# 25%     0.060670           0.013874        0.191423          0.108341
# 50%     0.088891           0.033687        0.219631          0.162796
# 75%     0.108091           0.058694        0.252165          0.205072
# max     0.171407           0.127325        0.310133          0.352913
#
#        CD4+Tcells  CD45RA+Tregs  CD45RA-Tregs  CD56+CD16-NKcells  CD7+NKcells  \
# count   68.000000     68.000000     68.000000          68.000000    68.000000
# mean     0.395832      0.006035      0.010955           0.004799     0.073156
# std      0.076555      0.003800      0.003607           0.002945     0.032396
# ...

# %%
df_meta = pd.read_csv(path + '/data/challenge-meta-information.csv')
df_meta.head()
# Out:
#    time    GA SampleID randPerson   data
# 0     1  11.0       K1          K  train
# 1     1  11.0       J1          J  train
# 2     1  11.0       P1          P  train
# 3     1  11.0       L1          L  train
# 4     1  11.0       H1          H  train

# %%
df=df_immun.merge(df_meta, on='SampleID')
df.head()
# Out:
#   SampleID    Bcells  CD16+CD56-NKcells  CD4+Tcells_mem  CD4+Tcells_naive  \
# 0       K4  0.053164           0.054978        0.297875          0.136289
# 1       I4  0.137333           0.061311        0.274281          0.139593
# 2       J4  0.103067           0.004128        0.162746          0.103950
# 3       P4  0.149802           0.058161        0.141881          0.257104
# 4       L4  0.124177           0.037422        0.235283          0.132742
#
#    CD4+Tcells  CD45RA+Tregs  CD45RA-Tregs  CD56+CD16-NKcells  CD7+NKcells  \
# 0    0.445832      0.002570      0.013848           0.007052     0.070836
# 1    0.422238      0.004931      0.013510           0.004393     0.075063
# 2    0.270840      0.003198      0.007988           0.007153     0.090763
# 3    0.406758      0.013168      0.009568           0.002663     0.069008
# 4    0.374535      0.003886      0.008935           0.001813     0.044584
#
# ...

# %%
df_serum = pd.read_csv(path + '/data/train/SerumLuminex.csv')
df_serum.head()
# Out:
#   SampleID  serum-IL17F  serum-FASL  serum-TGFA  serum-MIP1A  serum-SDF1A  \
# 0       K4         84.5       27.00       65.25        46.50       226.00
# 1       I4        126.0       23.25       66.75        40.00       183.50
# 2       J4        570.5       38.50       76.50        77.50       248.50
# 3       P4        140.0       22.25       48.50        68.75       231.50
# 4       L4        513.5      281.25       54.00       491.75       728.25
#
#    serum-IL27  serum-LIF  serum-IL1B  serum-IL2  ...  serum-ICAM1  \
# 0        36.5       52.0       33.50       38.0  ...      1679.00
# 1        32.0       47.0       20.75       54.5  ...       715.75
# 2        55.0      147.0       40.75      106.0  ...      1008.25
# 3        32.5       32.0       34.50       30.5  ...       378.00
# 4        93.0       85.0      284.50       84.0  ...      1223.50
#
#    serum-VCAM1  serum-FGFB  serum-IL22  serum-PDGFBB  serum-VEGF  \
# ...

# %%
df=df.merge(df_serum, on='SampleID')
df.head()
# Out:
#   SampleID    Bcells  CD16+CD56-NKcells  CD4+Tcells_mem  CD4+Tcells_naive  \
# 0       K4  0.053164           0.054978        0.297875          0.136289
# 1       I4  0.137333           0.061311        0.274281          0.139593
# 2       J4  0.103067           0.004128        0.162746          0.103950
# 3       P4  0.149802           0.058161        0.141881          0.257104
# 4       L4  0.124177           0.037422        0.235283          0.132742
#
#    CD4+Tcells  CD45RA+Tregs  CD45RA-Tregs  CD56+CD16-NKcells  CD7+NKcells  \
# 0    0.445832      0.002570      0.013848           0.007052     0.070836
# 1    0.422238      0.004931      0.013510           0.004393     0.075063
# 2    0.270840      0.003198      0.007988           0.007153     0.090763
# 3    0.406758      0.013168      0.009568           0.002663     0.069008
# 4    0.374535      0.003886      0.008935           0.001813     0.044584
#
#    ...  serum-ICAM1  serum-VCAM1  serum-FGFB  serum-IL22  serum-PDGFBB  \
# ...

# %%
df_plasma_lumin = pd.read_csv(path +'/data/train/plasmaLuminex.csv')
df_plasma_lumin.head()
# Out:
#   SampleID  plasma-IL17F  plasma-FASL  plasma-TGFA  plasma-MIP1A  \
# 0       K4         59.00        82.00        27.75         46.00
# 1       I4         87.25       221.50        48.50         71.50
# 2       J4        686.50      1088.50       453.75        252.25
# 3       P4         91.25       112.75        31.00         91.00
# 4       L4        186.75       544.75       194.25        171.25
#
#    plasma-SDF1A  plasma-IL27  plasma-LIF  plasma-IL1B  plasma-IL2  ...  \
# 0        191.25         70.5       35.50        28.00       31.00  ...
# 1        186.25        192.5       31.00        22.00       23.50  ...
# 2        575.50       1028.5      232.00        58.25      147.50  ...
# 3        272.00        104.5       34.50        32.00       32.75  ...
# 4        345.75        389.5       40.75        36.50       51.00  ...
#
#    plasma-ICAM1  plasma-VCAM1  plasma-FGFB  plasma-IL22  plasma-PDGFBB  \
# 0       1578.50      15781.00        50.50      43.0000          62.50
# ...

# %%
df=df.merge(df_plasma_lumin, on='SampleID')
df.head()
# Out:
#   SampleID    Bcells  CD16+CD56-NKcells  CD4+Tcells_mem  CD4+Tcells_naive  \
# 0       K4  0.053164           0.054978        0.297875          0.136289
# 1       I4  0.137333           0.061311        0.274281          0.139593
# 2       J4  0.103067           0.004128        0.162746          0.103950
# 3       P4  0.149802           0.058161        0.141881          0.257104
# 4       L4  0.124177           0.037422        0.235283          0.132742
#
#    CD4+Tcells  CD45RA+Tregs  CD45RA-Tregs  CD56+CD16-NKcells  CD7+NKcells  \
# 0    0.445832      0.002570      0.013848           0.007052     0.070836
# 1    0.422238      0.004931      0.013510           0.004393     0.075063
# 2    0.270840      0.003198      0.007988           0.007153     0.090763
# 3    0.406758      0.013168      0.009568           0.002663     0.069008
# 4    0.374535      0.003886      0.008935           0.001813     0.044584
#
# ...

# %%
df_plasma_somal = pd.read_csv(path +'/data/train/plasmaSomalogic.csv')
df_plasma_somal.head()
# Out:
#   SampleID   STUB1  CEBPB    ENO2  PIAS4  IL10RA  STAT3    IRF1   MCL1   OAS1  \
# 0       K1  1084.0  396.2  7065.9  490.7   702.9  761.0  1003.2  443.4  140.7
# 1       I1   916.7  492.2  6341.9  518.6   691.7  922.3  1226.6  728.3  328.1
# 2       J1   744.4  541.4  8916.0  615.5   742.4  595.8  2336.8  614.6  162.3
# 3       P1   831.0  544.7  5317.6  504.9   837.8  944.0  1011.6  459.2  150.6
# 4       L1  1033.4  558.4  4022.1  548.6   742.9  891.4  1146.8  522.3  148.4
#
#    ...  UBE2G2  TAGLN2   ATP5O  POMC.2  CRYZL1  SERPINF1    CTSF    FTCD  \
# 0  ...  4804.4  2233.0  3610.9   365.4   151.4   37885.8  1479.1  3261.8
# 1  ...  5023.5  2108.8  2679.9   370.1   191.8   32384.0  1557.6  1950.0
# 2  ...  4261.9  1804.6  1470.6   410.8   163.0   38938.3  1170.1  1036.8
# 3  ...  4017.6  2057.7  2331.3   567.5   178.1   34359.5  1427.1  3149.2
# 4  ...  4489.4  2653.4  2189.1   569.8   176.3   35281.1  1944.2  3266.7
#
#    USP25  PLXNB2
# 0  561.3  3227.0
# 1  701.3  3179.1
# ...

# %%
df=df.merge(df_plasma_somal, on='SampleID')
df.head()
# Out:
#   SampleID    Bcells  CD16+CD56-NKcells  CD4+Tcells_mem  CD4+Tcells_naive  \
# 0       K4  0.053164           0.054978        0.297875          0.136289
# 1       I4  0.137333           0.061311        0.274281          0.139593
# 2       J4  0.103067           0.004128        0.162746          0.103950
# 3       P4  0.149802           0.058161        0.141881          0.257104
# 4       L4  0.124177           0.037422        0.235283          0.132742
#
#    CD4+Tcells  CD45RA+Tregs  CD45RA-Tregs  CD56+CD16-NKcells  CD7+NKcells  \
# 0    0.445832      0.002570      0.013848           0.007052     0.070836
# 1    0.422238      0.004931      0.013510           0.004393     0.075063
# 2    0.270840      0.003198      0.007988           0.007153     0.090763
# 3    0.406758      0.013168      0.009568           0.002663     0.069008
# 4    0.374535      0.003886      0.008935           0.001813     0.044584
#
# ...

# %%
df_cfrna = pd.read_csv(path +'/data/train/cfRNA.csv')
df_cfrna.head()
# Out:
#   SampleID   C2orf76        ACTL10     CEP135  RP11-613M10.6      NDUFB5P1  \
# 0       K1  0.312437 -1.892930e-16  28.217854  -5.273559e-18 -6.106227e-18
# 1       I1  1.849737  0.000000e+00  54.567231   9.248683e-01  0.000000e+00
# 2       J1  5.204209  1.734736e+00  53.776824   0.000000e+00  0.000000e+00
# 3       P1  0.000000  0.000000e+00  15.269087   0.000000e+00  0.000000e+00
# 4       L1  0.000000  0.000000e+00  11.048308   0.000000e+00  0.000000e+00
#
#         MIIP  RP11-98I9.4     C20orf144  RP11-485G7.6  ...  LL22NC03-86G7.1  \
# 0  10.107555     0.070008 -3.885781e-16 -4.113376e-16  ...         0.707989
# 1  17.110064     2.774605  0.000000e+00  0.000000e+00  ...         0.000000
# 2   4.336841     1.734736  0.000000e+00  0.000000e+00  ...         1.734736
# 3   0.000000     0.000000  0.000000e+00  0.000000e+00  ...         3.053817
# 4  19.886954     2.209662  0.000000e+00  0.000000e+00  ...         0.000000
#
# ...

# %%
df=df.merge(df_cfrna, on='SampleID')
df.head()
# Out:
#   SampleID    Bcells  CD16+CD56-NKcells  CD4+Tcells_mem  CD4+Tcells_naive  \
# 0       K4  0.053164           0.054978        0.297875          0.136289
# 1       I4  0.137333           0.061311        0.274281          0.139593
# 2       J4  0.103067           0.004128        0.162746          0.103950
# 3       P4  0.149802           0.058161        0.141881          0.257104
# 4       L4  0.124177           0.037422        0.235283          0.132742
#
#    CD4+Tcells  CD45RA+Tregs  CD45RA-Tregs  CD56+CD16-NKcells  CD7+NKcells  \
# 0    0.445832      0.002570      0.013848           0.007052     0.070836
# 1    0.422238      0.004931      0.013510           0.004393     0.075063
# 2    0.270840      0.003198      0.007988           0.007153     0.090763
# 3    0.406758      0.013168      0.009568           0.002663     0.069008
# 4    0.374535      0.003886      0.008935           0.001813     0.044584
#
#    ...  LL22NC03-86G7.1      DNAL4       PPM1F     CCDC94      CLN6  \
# ...

# %%
df_metab = pd.read_csv(path +'/data/train/metabolome.csv',encoding= 'unicode_escape')
df_metab.head()
# Out:
#   SampleID  \
# 0       K1
# 1       I1
# 2       J1
# 3       P1
# 4       L1
#
#    N1-Methyl-2-pyridone-5-carboxamide|N1-Methyl-4-pyridone-3-carboxamide|N-[(Aminooxy)Carbonyl]Aniline  \
# 0                                          -0.103676
# 1                                          -0.106104
# 2                                          -0.090160
# 3                                          -0.122656
# 4                                          -0.117107
#
#    Barringtogenol C|Camelliagenin C|Ganoderiol H|ED-71  \
# 0                                          -0.107316
# 1                                          -0.102340
# 2                                          -0.095522
# 3                                          -0.122855
# 4                                          -0.041200
#
#    3beta-Acetoxy-11alpha-methoxy-12-ursen-28-oic acid  Basilimoside  \
# 0                                          -0.114072      -0.123576
# ...

# %%
df=df.merge(df_metab, on='SampleID')
df.head()
# Out:
#   SampleID    Bcells  CD16+CD56-NKcells  CD4+Tcells_mem  CD4+Tcells_naive  \
# 0       K4  0.053164           0.054978        0.297875          0.136289
# 1       I4  0.137333           0.061311        0.274281          0.139593
# 2       J4  0.103067           0.004128        0.162746          0.103950
# 3       P4  0.149802           0.058161        0.141881          0.257104
# 4       L4  0.124177           0.037422        0.235283          0.132742
#
#    CD4+Tcells  CD45RA+Tregs  CD45RA-Tregs  CD56+CD16-NKcells  CD7+NKcells  \
# 0    0.445832      0.002570      0.013848           0.007052     0.070836
# 1    0.422238      0.004931      0.013510           0.004393     0.075063
# 2    0.270840      0.003198      0.007988           0.007153     0.090763
# 3    0.406758      0.013168      0.009568           0.002663     0.069008
# 4    0.374535      0.003886      0.008935           0.001813     0.044584
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
# ...

# %%
df_micro = pd.read_csv(path +'/data/train/microbiome.csv')
df_micro.head()
# Out:
#   SampleID  VaginalSwab_Lactobacillus  Saliva_Lactobacillus  \
# 0       K1                 103.491092              0.435833
# 1       I1                   0.108275             -0.028496
# 2       J1                  -0.027296             -0.027296
# 3       P1                  -0.016359             -0.032342
# 4       L1                  -0.031554             -0.031554
#
#    ToothGum_Lactobacillus  Stool_Lactobacillus  VaginalSwab_Lactobacillus.1  \
# 0                0.004819             1.266310                   103.491092
# 1               -0.022462             0.057991                     0.108275
# 2               -0.027296            -0.027296                    -0.027296
# 3               -0.032342            -0.032342                    -0.016359
# 4               -0.031554            -0.031554                    -0.031554
#
#    Saliva_Lactobacillus.1  ToothGum_Lactobacillus.1  Stool_Lactobacillus.1  \
# ...

# %%
df=df.merge(df_micro, on='SampleID')
df.head()
# Out:
#   SampleID    Bcells  CD16+CD56-NKcells  CD4+Tcells_mem  CD4+Tcells_naive  \
# 0       K4  0.053164           0.054978        0.297875          0.136289
# 1       I4  0.137333           0.061311        0.274281          0.139593
# 2       J4  0.103067           0.004128        0.162746          0.103950
# 3       P4  0.149802           0.058161        0.141881          0.257104
# 4       L4  0.124177           0.037422        0.235283          0.132742
#
#    CD4+Tcells  CD45RA+Tregs  CD45RA-Tregs  CD56+CD16-NKcells  CD7+NKcells  \
# 0    0.445832      0.002570      0.013848           0.007052     0.070836
# 1    0.422238      0.004931      0.013510           0.004393     0.075063
# 2    0.270840      0.003198      0.007988           0.007153     0.090763
# 3    0.406758      0.013168      0.009568           0.002663     0.069008
# 4    0.374535      0.003886      0.008935           0.001813     0.044584
#
# ...

# %%
df_copy = df.copy()

# %%
train = df[df.data == 'train']
test = df[df.data == 'test']

# %%
len(test)
# Out:
# 12

# %%
y_train = train.GA
y_test = test.GA

# %%
X_train = train.drop(['GA','time','randPerson','SampleID','data'], axis=1)
X_test = test.drop(['GA','time','randPerson','SampleID','data'], axis=1)

# %%
X_test.head()
# Out:
#       Bcells  CD16+CD56-NKcells  CD4+Tcells_mem  CD4+Tcells_naive  CD4+Tcells  \
# 1   0.137333           0.061311        0.274281          0.139593    0.422238
# 12  0.112706           0.020985        0.186667          0.143901    0.337246
# 13  0.050658           0.024131        0.214453          0.088116    0.313028
# 18  0.119092           0.060294        0.277815          0.153793    0.440762
# 29  0.097618           0.016901        0.193449          0.169328    0.369726
#
#     CD45RA+Tregs  CD45RA-Tregs  CD56+CD16-NKcells  CD7+NKcells  \
# 1       0.004931      0.013510           0.004393     0.075063
# 12      0.006935      0.015591           0.003416     0.075746
# 13      0.000472      0.003323           0.003541     0.064603
# 18      0.006079      0.015419           0.005696     0.073532
# 29      0.007478      0.016845           0.002463     0.062421
#
#     CD8+Tcells_mem  ...  ToothGum_Azospirillum  Stool_Azospirillum  \
# ...

# %%
# Feature scaling
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler

num_pipeline = Pipeline([('min_max_scaler', MinMaxScaler())])
X_train_tr = num_pipeline.fit_transform(X_train)
# Out:
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %% [markdown]
# ## Random Forest

# %%
# Random forest
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=100 ,random_state=1)
rf_model.fit(X_train_tr, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
# training error
from sklearn.metrics import mean_absolute_error

preds_train = rf_model.predict(X_train_tr)
rf_train_err = mean_absolute_error(y_train, preds_train)
rf_train_err
# Out:
# 1.1195153061224488

# %%
# Cross Validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(rf_model, X_train_tr, y_train, 
                         scoring ='neg_mean_absolute_error', cv=10)
def display_scores(scores):
    print('Scores:', scores)
    print('Mean: ', scores.mean())
    print('Standard Deviation:', scores.std())
    
display_scores(-scores)
# Out:
# Scores: [7.01785714 5.11714286 2.65309524 3.1652381  1.77833333 1.66619048
#  2.53285714 3.25571429 3.21314286 7.92857143]
# Mean:  3.832814285714285
# Standard Deviation: 2.0427602853550964

# %%
rf_valid_err = -scores.mean()
rf_valid_err
# Out:
# 3.832814285714285

# %%
# Saving model
import joblib

joblib.dump(rf_model, 'rf_model.pkl')
# Out:
# ['rf_model.pkl']

# %%
from sklearn.model_selection import GridSearchCV
# 'max_features':[2,4,6,8]}
param_grid = [{'n_estimators':[10,100,1000]},
             {'bootstrap':[False],'n_estimators':[10,100,1000]}]
forest_reg = RandomForestRegressor()
grid_search = GridSearchCV(forest_reg, param_grid, cv=10, scoring ='neg_mean_absolute_error'
                          , return_train_score = True)
grid_search.fit(X_train_tr, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-64b63aca58fa> in <module>
#       6 grid_search = GridSearchCV(forest_reg, param_grid, cv=10, scoring ='neg_mean_absolute_error'
#       7                           , return_train_score = True)
# ----> 8 grid_search.fit(X_train_tr, y_train)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     721                 return results_container[0]
#     722
# --> 723             self._run_search(evaluate_candidates)
#     724
#     725         results = results_container[0]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1190     def _run_search(self, evaluate_candidates):
#    1191         """Search all candidates in param_grid"""
# ...

# %%
grid_search.best_params_
# Out:
# {'n_estimators': 1000}

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres['mean_test_score'], cvres['params']):
    print(-mean_score, params)
# Out:
# 4.052040816326531 {'n_estimators': 10}
# 3.893112244897959 {'n_estimators': 100}
# 3.619408163265303 {'n_estimators': 1000}
# 4.8025510204081625 {'bootstrap': False, 'n_estimators': 10}
# 4.53359693877551 {'bootstrap': False, 'n_estimators': 100}
# 4.537772959183672 {'bootstrap': False, 'n_estimators': 1000}

# %% [markdown]
# ## Elastic Net

# %%
from sklearn.linear_model import ElasticNet
elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5)
elastic_net.fit(X_train_tr, y_train)
# Out:
# ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
# Training error
preds_train = elastic_net.predict(X_train_tr)
mean_absolute_error(y_train, preds_train)
# Out:
# 0.578320928719352

# %%
scores = cross_val_score(elastic_net, X_train_tr, y_train, 
                         scoring ='neg_mean_absolute_error', cv=10)
display_scores(-scores)
# Out:
# Scores: [4.21351506 2.39634045 2.10478659 2.17813962 1.67593668 0.94172084
#  1.52898802 2.55410377 2.52220967 5.56005586]
# Mean:  2.5675796561611226
# Standard Deviation: 1.2875767056293836

# %%
joblib.dump(elastic_net, 'elastic_net.pkl')
# Out:
# ['elastic_net.pkl']

# %%
param_grid = [{'alpha':[0.1,0.5,0.8], 'l1_ratio':[0.1,0.5,0.8]}]
elastic_reg = ElasticNet()
grid_search = GridSearchCV(elastic_reg, param_grid, cv=10, scoring ='neg_mean_absolute_error'
                          , return_train_score = True)
enet_model = grid_search.fit(X_train_tr, y_train)
# Out:
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
grid_search.best_params_
# Out:
# {'alpha': 0.1, 'l1_ratio': 0.8}

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres['mean_test_score'], cvres['params']):
    print(-mean_score, params)
# Out:
# 2.919244612354155 {'alpha': 0.1, 'l1_ratio': 0.1}
# 2.5337396792965428 {'alpha': 0.1, 'l1_ratio': 0.5}
# 2.4127806964565193 {'alpha': 0.1, 'l1_ratio': 0.8}
# 3.3130850090745647 {'alpha': 0.5, 'l1_ratio': 0.1}
# 3.5321736183341805 {'alpha': 0.5, 'l1_ratio': 0.5}
# 3.779115368597386 {'alpha': 0.5, 'l1_ratio': 0.8}
# 3.6000494259514766 {'alpha': 0.8, 'l1_ratio': 0.1}
# 4.310538476477491 {'alpha': 0.8, 'l1_ratio': 0.5}
# 4.753571582141453 {'alpha': 0.8, 'l1_ratio': 0.8}

# %%
y_preds = enet_model.predict(X_train_tr)
enet_train_err = mean_absolute_error(y_train, y_preds)
enet_train_err
# Out:
# 0.7526600018929701

# %%
enet_valid_err = min(-cvres['mean_test_score'])
enet_valid_err
# Out:
# 2.4127806964565193

# %% [markdown]
# ## Neural net

# %%
import tensorflow as tf
from tensorflow import keras
keras.__version__
# Out:
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
tf.__version__
# Out:
# '1.13.1'

# %%
X_train_tr.shape[1:]
# Out:
# (61266,)

# %%
from sklearn.model_selection import train_test_split

X_train_tr1, X_valid, y_train1, y_valid = train_test_split(X_train_tr, y_train )

# %%
model = keras.models.Sequential([keras.layers.Dense(300, activation='relu',
                                                   input_shape=X_train_tr.shape[1:]),
                                  keras.layers.Dense(150, activation ='relu'),
                                keras.layers.Dense(1)])
model.compile(loss='mean_absolute_error', optimizer='sgd')
history = model.fit(X_train_tr1, y_train1, epochs=20, validation_data = [X_valid, y_valid])
# Out:
# WARNING:tensorflow:From /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Train on 42 samples, validate on 14 samples
# WARNING:tensorflow:From /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 42/42 [==============================] - 1s 21ms/sample - loss: 12.7687 - val_loss: 9.3838
# Epoch 2/20
# 42/42 [==============================] - 0s 6ms/sample - loss: 9.6581 - val_loss: 9.9930
# Epoch 3/20
# 42/42 [==============================] - 0s 5ms/sample - loss: 8.4027 - val_loss: 12.9321
# Epoch 4/20
# ...

# %%
history = model.fit(X_train_tr1, y_train1, epochs=20, validation_data = [X_valid, y_valid])
# Out:
# Train on 42 samples, validate on 14 samples
# Epoch 1/20
# 42/42 [==============================] - 0s 6ms/sample - loss: 7.9794 - val_loss: 9.3913
# Epoch 2/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 4.5405 - val_loss: 7.5684
# Epoch 3/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 2.8844 - val_loss: 5.9938
# Epoch 4/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 4.4774 - val_loss: 5.5471
# Epoch 5/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 5.1178 - val_loss: 7.8314
# Epoch 6/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 3.3027 - val_loss: 8.1608
# Epoch 7/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 4.1205 - val_loss: 11.7301
# Epoch 8/20
# 42/42 [==============================] - 0s 7ms/sample - loss: 8.3207 - val_loss: 7.7621
# Epoch 9/20
# 42/42 [==============================] - 0s 8ms/sample - loss: 3.7745 - val_loss: 8.0283
# Epoch 10/20
# ...

# %%
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
#plt.gca().set_ylim(0,1)
plt.show()

# %%
mlp_train_err = model.evaluate(X_train_tr, y_train)
mlp_train_err
# Out:
# 56/56 [==============================] - 0s 1ms/sample - loss: 4.6457
# 4.645695890699114

# %%
mlp_valid_err = model.evaluate(X_valid, y_valid)
mlp_valid_err
# Out:
# 14/14 [==============================] - 0s 1ms/sample - loss: 6.8860
# 6.886046409606934

# %% [markdown]
# ## Test Set

# %%
X_test_tr = num_pipeline.transform(X_test)

# %%
rf_test_preds = rf_model.predict(X_test_tr)
rf_test_err = mean_absolute_error(y_test,rf_test_preds)
rf_test_err
# Out:
# 2.264761904761905

# %%
enet_test_preds = enet_model.predict(X_test_tr)
enet_test_err = mean_absolute_error(y_test,enet_test_preds)
enet_test_err
# Out:
# 2.9582418971757036

# %%
mlp_test_err = model.evaluate(X_test_tr, y_test)
mlp_test_err
# Out:
# 12/12 [==============================] - 0s 1ms/sample - loss: 395901048734089216.0000
# 3.959010487340892e+17

# %%
data = {'Random Forest':[rf_train_err, rf_valid_err, rf_test_err],
        'Elastic Net':[enet_train_err, enet_valid_err, enet_test_err],
        'MLP':[mlp_train_err, mlp_valid_err, mlp_test_err]}
results = pd.DataFrame(data, index=['train_mae','valid_mae','test_mae'])
results
# Out:
#            Random Forest  Elastic Net           MLP
# train_mae       1.119515     0.752660  4.645696e+00
# valid_mae       3.832814     2.412781  6.886046e+00
# test_mae        2.264762     2.958242  3.959010e+17

# %%
rf_test_preds
# Out:
# array([ 0.31714286,  0.81714286,  8.36285714, 13.28714286, 12.98857143,
#        11.69285714, 14.77142857, 16.12      , 17.13571429, 23.83      ,
#        23.56714286, 22.93      ])

# %%
test
# Out:
#    SampleID    Bcells  CD16+CD56-NKcells  CD4+Tcells_mem  CD4+Tcells_naive  \
# 1        I4  0.137333           0.061311        0.274281          0.139593
# 12       W4  0.112706           0.020985        0.186667          0.143901
# 13       B4  0.050658           0.024131        0.214453          0.088116
# 18       I1  0.119092           0.060294        0.277815          0.153793
# 29       W1  0.097618           0.016901        0.193449          0.169328
# 30       B1  0.052293           0.010642        0.217094          0.096288
# 35       I2  0.116981           0.048495        0.241318          0.180908
# 46       W2  0.102321           0.014489        0.177417          0.181568
# 47       B2  0.039824           0.021531        0.209109          0.118017
# 52       I3  0.096353           0.068407        0.257616          0.173699
# 63       W3  0.077124           0.014504        0.192619          0.189237
# ...

# %%
df_sub = test[['SampleID','GA']]
df_sub
# Out:
#    SampleID         GA
# 1        I4   2.571429
# 12       W4   0.571429
# 13       B4   0.571429
# 18       I1  11.000000
# 29       W1  11.000000
# 30       B1  11.000000
# 35       I2  15.000000
# 46       W2  18.000000
# 47       B2  16.000000
# 52       I3  25.000000
# 63       W3  27.000000
# 64       B3  27.000000

# %%
df_sub['predicted.GA'] = rf_test_preds
df_sub
# Out:
# /Users/mparvatham/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    SampleID         GA  predicted.GA
# 1        I4   2.571429      0.317143
# 12       W4   0.571429      0.817143
# 13       B4   0.571429      8.362857
# 18       I1  11.000000     13.287143
# 29       W1  11.000000     12.988571
# 30       B1  11.000000     11.692857
# 35       I2  15.000000     14.771429
# 46       W2  18.000000     16.120000
# 47       B2  16.000000     17.135714
# 52       I3  25.000000     23.830000
# 63       W3  27.000000     23.567143
# 64       B3  27.000000     22.930000

# %%
df_sub.to_csv('GROUP-4--SC3--RF.csv')
